# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample data: Hours studied vs Marks scored
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Independent variable
y = np.array([30, 50, 60, 70, 80])           # Dependent variable

# Create and train the model
model = LinearRegression()
model.fit(X, y)

# Predict marks for 6 hours of study
predicted_marks = model.predict([[6]])
print(f"Predicted Marks for 6 hours of study: {predicted_marks[0]:.2f}")

# Plot the data and regression line
plt.scatter(X, y, color='blue', label='Actual Marks')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel("Hours Studied")
plt.ylabel("Marks Scored")
plt.title("Simple Linear Regression: Hours vs Marks")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predicted Marks for 6 hours of study: 94.00
